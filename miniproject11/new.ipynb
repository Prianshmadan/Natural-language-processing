# %%
import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
import random
import datetime
from googlesearch import *
import webbrowser
import requests
from nba_api.stats.static import teams
from nba_api.stats.endpoints import scoreboard
import billboard
import time
from pygame import mixer
import requests
from datetime import date

# Get all NBA teams


from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file=open('intents.json').read()
intents=json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w=nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

#training data
training=[]
output_empty=[0]*len(classes)

for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ]
    
    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0)
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1
    
    training.append([bag,output_row])
    
random.shuffle(training)
training=np.array(training)  
X_train=list(training[:,0])
y_train=list(training[:,1])  

#Model
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(X_train[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]),activation='softmax'))

adam=keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)
weights=model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)    
model.save('mymodel.h5',weights)
# Out:
# Epoch 1/200
# C:\Users\prian\AppData\Local\Temp\ipykernel_28232\1702137471.py:70: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training=np.array(training)
# 12/12 [==============================] - 1s 3ms/step - loss: 3.4056 - accuracy: 0.0265
# Epoch 2/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3797 - accuracy: 0.0531
# Epoch 3/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3695 - accuracy: 0.0973
# Epoch 4/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3391 - accuracy: 0.0973
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.2994 - accuracy: 0.1239
# Epoch 6/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2887 - accuracy: 0.0708
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.2542 - accuracy: 0.1327
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1991 - accuracy: 0.1239
# Epoch 9/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1807 - accuracy: 0.1239
# Epoch 10/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1012 - accuracy: 0.1681
# Epoch 11/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0964 - accuracy: 0.1504
# Epoch 12/200
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0450 - accuracy: 0.1681
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9578 - accuracy: 0.2212
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9050 - accuracy: 0.1858
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8205 - accuracy: 0.2389
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7009 - accuracy: 0.3097
# Epoch 17/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7146 - accuracy: 0.2566
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5970 - accuracy: 0.3363
# Epoch 19/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4596 - accuracy: 0.3363
# Epoch 20/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4581 - accuracy: 0.3274
# Epoch 21/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3369 - accuracy: 0.3009
# Epoch 22/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1985 - accuracy: 0.3363
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3084 - accuracy: 0.3451
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1403 - accuracy: 0.4159
# Epoch 25/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0421 - accuracy: 0.4248
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9413 - accuracy: 0.5044
# Epoch 27/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9790 - accuracy: 0.4071
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8381 - accuracy: 0.4513
# Epoch 29/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.6481 - accuracy: 0.6018
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7901 - accuracy: 0.4690
# Epoch 31/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6378 - accuracy: 0.5487
# Epoch 32/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4673 - accuracy: 0.5664
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6041 - accuracy: 0.4867
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4404 - accuracy: 0.5487
# Epoch 35/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4399 - accuracy: 0.5575
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2668 - accuracy: 0.6726
# Epoch 37/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3291 - accuracy: 0.5929
# Epoch 38/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2648 - accuracy: 0.6637
# Epoch 39/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2746 - accuracy: 0.6106
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0493 - accuracy: 0.7345
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1345 - accuracy: 0.6903
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0769 - accuracy: 0.6549
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0386 - accuracy: 0.7434
# Epoch 44/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1019 - accuracy: 0.6372
# Epoch 45/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9455 - accuracy: 0.7434
# Epoch 46/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0220 - accuracy: 0.6991
# Epoch 47/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9103 - accuracy: 0.7699
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9901 - accuracy: 0.6991
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9852 - accuracy: 0.6991
# Epoch 50/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8950 - accuracy: 0.7434
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.8142
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8726 - accuracy: 0.7699
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7779 - accuracy: 0.7611
# Epoch 54/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7079 - accuracy: 0.8319
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.8142
# Epoch 56/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7339 - accuracy: 0.7611
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.8850
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.8319
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7176 - accuracy: 0.7965
# Epoch 60/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7060 - accuracy: 0.8584
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.8053
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.8850
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6274 - accuracy: 0.8142
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.9027
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6230 - accuracy: 0.8407
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5354 - accuracy: 0.8673
# Epoch 67/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.8407
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.8584
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.8938
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.8850
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4971 - accuracy: 0.8584
# Epoch 72/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.8850
# Epoch 73/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5206 - accuracy: 0.8407
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.8496
# Epoch 75/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.8142
# Epoch 76/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4980 - accuracy: 0.8407
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.9027
# Epoch 78/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4448 - accuracy: 0.8761
# Epoch 79/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.9027
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4273 - accuracy: 0.8938
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8938
# Epoch 82/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3845 - accuracy: 0.9204
# Epoch 83/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3060 - accuracy: 0.9381
# Epoch 84/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.9027
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.8850
# Epoch 86/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.9027
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8938
# Epoch 88/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.8584
# Epoch 89/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3168 - accuracy: 0.9292
# Epoch 90/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2641 - accuracy: 0.9469
# Epoch 91/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3097 - accuracy: 0.9381
# Epoch 92/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2809 - accuracy: 0.9381
# Epoch 93/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3521 - accuracy: 0.9204
# Epoch 94/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3225 - accuracy: 0.9027
# Epoch 95/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.9204
# Epoch 96/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.8761
# Epoch 97/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3191 - accuracy: 0.9292
# Epoch 98/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2341 - accuracy: 0.9558
# Epoch 99/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3023 - accuracy: 0.9204
# Epoch 100/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2983 - accuracy: 0.9204
# Epoch 101/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2748 - accuracy: 0.9115
# Epoch 102/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1866 - accuracy: 0.9646
# Epoch 103/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3132 - accuracy: 0.9204
# Epoch 104/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2052 - accuracy: 0.9469
# Epoch 105/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2966 - accuracy: 0.9204
# Epoch 106/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.9115
# Epoch 107/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2431 - accuracy: 0.9292
# Epoch 108/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3390 - accuracy: 0.9027
# Epoch 109/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2496 - accuracy: 0.9027
# Epoch 110/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2946 - accuracy: 0.9469
# Epoch 111/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2876 - accuracy: 0.8938
# Epoch 112/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2309 - accuracy: 0.9292
# Epoch 113/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2604 - accuracy: 0.9204
# Epoch 114/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2573 - accuracy: 0.9292
# Epoch 115/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2576 - accuracy: 0.9469
# Epoch 116/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9381
# Epoch 117/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2274 - accuracy: 0.9469
# Epoch 118/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2593 - accuracy: 0.9204
# Epoch 119/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1861 - accuracy: 0.9558
# Epoch 120/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3180 - accuracy: 0.8938
# Epoch 121/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2230 - accuracy: 0.9204
# Epoch 122/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.8938
# Epoch 123/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2647 - accuracy: 0.9115
# Epoch 124/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1915 - accuracy: 0.9292
# Epoch 125/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1806 - accuracy: 0.9558
# Epoch 126/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1923 - accuracy: 0.9735
# Epoch 127/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.9115
# Epoch 128/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2488 - accuracy: 0.9204
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.9204
# Epoch 130/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2044 - accuracy: 0.9469
# Epoch 131/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2187 - accuracy: 0.9646
# Epoch 132/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9558
# Epoch 133/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2101 - accuracy: 0.9558
# Epoch 134/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2329 - accuracy: 0.9381
# Epoch 135/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2133 - accuracy: 0.9381
# Epoch 136/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2441 - accuracy: 0.9292
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3205 - accuracy: 0.8938
# Epoch 138/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2440 - accuracy: 0.9027
# Epoch 139/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2175 - accuracy: 0.9469
# Epoch 140/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1685 - accuracy: 0.9646
# Epoch 141/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2416 - accuracy: 0.9204
# Epoch 142/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.9381
# Epoch 143/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1470 - accuracy: 0.9558
# Epoch 144/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1806 - accuracy: 0.9469
# Epoch 145/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.9469
# Epoch 146/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1097 - accuracy: 0.9735
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1527 - accuracy: 0.9292
# Epoch 148/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2134 - accuracy: 0.9558
# Epoch 149/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1831 - accuracy: 0.9292
# Epoch 150/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1905 - accuracy: 0.9469
# Epoch 151/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9558
# Epoch 152/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2253 - accuracy: 0.9381
# Epoch 153/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9469
# Epoch 154/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.9823
# Epoch 155/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9469
# Epoch 156/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2418 - accuracy: 0.9027
# Epoch 157/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.9646
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9558
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9735
# Epoch 160/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.9381
# Epoch 161/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1579 - accuracy: 0.9558
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9469
# Epoch 163/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1754 - accuracy: 0.9292
# Epoch 164/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.9558
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9469
# Epoch 166/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2379 - accuracy: 0.9115
# Epoch 167/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9735
# Epoch 168/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9292
# Epoch 169/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9735
# Epoch 170/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9469
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9558
# Epoch 172/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1157 - accuracy: 0.9735
# Epoch 173/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1828 - accuracy: 0.9558
# Epoch 174/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9646
# Epoch 175/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.9558
# Epoch 176/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9292
# Epoch 177/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1184 - accuracy: 0.9646
# Epoch 178/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9735
# Epoch 179/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9469
# Epoch 180/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9646
# Epoch 181/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.9558
# Epoch 182/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1112 - accuracy: 0.9646
# Epoch 183/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1810 - accuracy: 0.9469
# Epoch 184/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 0.9558
# Epoch 185/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1486 - accuracy: 0.9558
# Epoch 186/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1559 - accuracy: 0.9469
# Epoch 187/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9735
# Epoch 188/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9735
# Epoch 189/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1429 - accuracy: 0.9558
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9646
# Epoch 191/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9646
# Epoch 192/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2200 - accuracy: 0.9381
# Epoch 193/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0796 - accuracy: 0.9912
# Epoch 194/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1966 - accuracy: 0.9292
# Epoch 195/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1742 - accuracy: 0.9469
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9646
# Epoch 197/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9823
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1110 - accuracy: 0.9646
# Epoch 199/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2162 - accuracy: 0.9381
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9469

# %%
from keras.models import load_model
model = load_model('mymodel.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


#Predict
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))
    
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]
    
    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

def get_response(return_list,intents_json):
    
    if len(return_list)==0:
        tag='noanswer'
    else:    
        tag=return_list[0]['intent']
    if tag=='datetime':        
        print(time.strftime("%A"))
        print (time.strftime("%d %B %Y"))
        print (time.strftime("%H:%M:%S"))

    if tag=='google':
        num_results = 1
        query=input('Enter query...')
        chrome_path = r'C://Program Files (x86)//Google//Chrome//Application//chrome.exe %s'
        for url in search(query, num_results=num_results):
            webbrowser.open("https://google.com/search?q=%s" % query)
    if tag=='weather':
        api_key='987f44e8c16780be8c85e25a409ed07b'
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        city_name = input("Enter city name : ")
        complete_url = base_url + "appid=" + api_key + "&q=" + city_name
        response = requests.get(complete_url) 
        x=response.json()
        print('Present temp.: ',round(x['main']['temp']-273,2),'celcius ')
        print('Feels Like:: ',round(x['main']['feels_like']-273,2),'celcius ')
        print(x['weather'][0]['main'])
        
    if tag=='news':
        main_url = " http://newsapi.org/v2/top-headlines?country=in&apiKey=bc88c2e1ddd440d1be2cb0788d027ae2"
        open_news_page = requests.get(main_url).json()
        article = open_news_page["articles"]
        results = [] 
          
        for ar in article: 
            results.append([ar["title"],ar["url"]]) 
          
        for i in range(10): 
            print(i + 1, results[i][0])
            print(results[i][1],'\n')
    
    if tag=='song':
        chart=billboard.ChartData('hot-100')
        print('The top 10 songs at the moment are:')
        for i in range(10):
            song=chart[i]
            print(song.title,'- ',song.artist)
    if tag=='timer':        
        mixer.init()
        x=input('Minutes to timer..')
        time.sleep(float(x)*60)
        mixer.music.load('Handbell-ringing-sound-effect.mp3')
        mixer.music.play()
        

    list_of_intents= intents_json['intents']    
    for i in list_of_intents:
        if tag==i['tag'] :
            result= random.choice(i['responses'])
    return result

def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response

while(1):
    x=input()
    print(response(x))
    if x.lower() in ['bye','goodbye','get lost','see you']:  
        break
# Out:
# 1/1 [==============================] - 0s 148ms/step
# Good to know!
# 1/1 [==============================] - 0s 34ms/step
# Glad I could make you laugh !
# 1/1 [==============================] - 0s 50ms/step
# Sorry, can't understand you
# 1/1 [==============================] - 0s 33ms/step
# Sorry, can't understand you
# 1/1 [==============================] - 0s 35ms/step
# Have a nice day
